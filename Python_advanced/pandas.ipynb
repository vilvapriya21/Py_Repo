# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached pandas-2.3.3-cp314-cp314-win_amd64.whl (11.1 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %%
import pandas as pd 

data = {
    'Name': ["Alice", "Bob", "Charlie"],
    'Age': [0, 18, 23],
    "City": ["Chennai", "Bangalore", "Hyderabad"]
}

df=pd.DataFrame(data)
print(df["Name"])   # Series
print(df[["Name"]]) # DataFrame
print(df)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
#       Name  Age       City
# 0    Alice    0    Chennai
# 1      Bob   18  Bangalore
# 2  Charlie   23  Hyderabad

# %%
df=pd.read_csv("Data/Zomato-data-.csv")

# %%
df.head()     # first 5 rows
df.tail()     # last 5 rows
df.shape     # (rows, columns)
df.columns   # column names
df.info()    # data types & nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df['name'] #one column

df[['name','online_order']] #multiple
# Out:
#                       name online_order
# 0                    Jalsa          Yes
# 1           Spice Elephant          Yes
# 2          San Churro Cafe          Yes
# 3    Addhuri Udupi Bhojana           No
# 4            Grand Village           No
# ..                     ...          ...
# 143       Melting Melodies           No
# 144        New Indraprasta           No
# 145           Anna Kuteera          Yes
# 146                 Darbar           No
# 147          Vijayalakshmi          Yes
#
# [148 rows x 2 columns]

# %% [markdown]
# loc (Label-based): Selects data by the names of the rows and columns.
#
# iloc (Integer-positional): Selects data by its numerical position (starting from 0), regardless of what the labels are.

# %%
df.iloc[0] #first row

df.iloc[0:5]

print(df.loc[20]) # row by index label
print(df.iloc[20])
# Out:
# name                           The Vintage Cafe
# online_order                                Yes
# book_table                                   No
# rate                                      3.0/5
# votes                                        62
# approx_cost(for two people)                 400
# listed_in(type)                           Cafes
# Name: 20, dtype: object
# name                           The Vintage Cafe
# online_order                                Yes
# book_table                                   No
# rate                                      3.0/5
# votes                                        62
# approx_cost(for two people)                 400
# listed_in(type)                           Cafes
# Name: 20, dtype: object

# %% [markdown]
# Filtering Data

# %%
df[df['online_order']=='Yes']

df[(df['online_order']=='Yes') & (df['book_table']=='Yes')]

df[(df['listed_in(type)']=='Buffet') & (df['approx_cost(for two people)']<1000)]
# Out:
#                                               name online_order book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# 5                                  Timepass Dinner          Yes         No
# 6  Rosewood International Hotel - Bar & Restaurant           No         No
#
#     rate  votes  approx_cost(for two people) listed_in(type)
# 0  4.1/5    775                          800          Buffet
# 1  4.1/5    787                          800          Buffet
# 2  3.8/5    918                          800          Buffet
# 3  3.7/5     88                          300          Buffet
# 4  3.8/5    166                          600          Buffet
# ...

# %%
df.isnull()
df.isnull().sum()
# Out:
#       name  online_order  book_table   rate  votes  \
# 0    False         False       False  False  False
# 1    False         False       False  False  False
# 2    False         False       False  False  False
# 3    False         False       False  False  False
# 4    False         False       False  False  False
# ..     ...           ...         ...    ...    ...
# 144  False         False       False  False  False
# 145  False         False       False  False  False
# 146  False         False       False  False  False
# 147  False         False       False  False  False
# 148  False         False       False  False  False
#
#      approx_cost(for two people)  listed_in(type)
# 0                          False            False
# 1                          False            False
# 2                          False            False
# 3                          False            False
# 4                          False            False
# ...

# %%
df.dropna()        # remove rows
df.fillna(0)       # replace with 0
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
# 148               my_hotel          Yes        Yes    0/0      0
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
# 148               my_hotel          Yes        Yes    0/0      0
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...
