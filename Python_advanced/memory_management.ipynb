# %%
import sys

a=[1,2,3]
b=a
print(sys.getrefcount(a))
# Out:
# 3

# %%
class A:
    pass

class B:
    pass

a = A()
b = B()

a.b = b
b.a = a
print(a.__dict__)
# Out:
# {'b': <__main__.B object at 0x00000193A6654050>}
