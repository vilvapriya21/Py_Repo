# %%
#pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.44-py3-none-any.whl.metadata (9.5 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.2.4-cp314-cp314-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\priya koma\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading sqlalchemy-2.0.44-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 6.0 MB/s  0:00:00
# Downloading greenlet-3.2.4-cp314-cp314-win_amd64.whl (303 kB)
# Installing collected packages: greenlet, sqlalchemy
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    ---------------------------------------- 2/2 [sqlalchemy]
#
# Successfully installed greenlet-3.2.4 sqlalchemy-2.0.44
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
engine=create_engine("sqlite:///Employees.db",echo=True)

from sqlalchemy.orm import declarative_base
Base = declarative_base()

from sqlalchemy import Column, Integer, String, Float

class Employee(Base):
    __tablename__ = "employees"

    id = Column(Integer, primary_key=True)
    name = Column(String(30))
    salary = Column(Float)

    def __repr__(self):
        return f"<Employee {self.id} {self.name} {self.salary}>"

Base.metadata.create_all(engine)
# Out:
# 2025-12-03 18:35:02,654 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-03 18:35:02,656 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("employees")
# 2025-12-03 18:35:02,658 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-03 18:35:02,661 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("employees")
# 2025-12-03 18:35:02,662 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-03 18:35:02,665 INFO sqlalchemy.engine.Engine
# CREATE TABLE employees (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(30),
# 	salary FLOAT,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-12-03 18:35:02,666 INFO sqlalchemy.engine.Engine [no key 0.00102s] ()
# 2025-12-03 18:35:02,682 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)
session = Session()

emp1 = Employee(name="Rama", salary=20000)
emp2 = Employee(name="Vilva", salary=500000)

session.add(emp1)
session.add(emp2)
session.commit()
# Out:
# 2025-12-03 18:36:55,949 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-03 18:36:55,962 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, salary) VALUES (?, ?) RETURNING id
# 2025-12-03 18:36:55,962 INFO sqlalchemy.engine.Engine [generated in 0.00087s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('Rama', 20000.0)
# 2025-12-03 18:36:55,965 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, salary) VALUES (?, ?) RETURNING id
# 2025-12-03 18:36:55,966 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] ('Vilva', 500000.0)
# 2025-12-03 18:36:55,968 INFO sqlalchemy.engine.Engine COMMIT
