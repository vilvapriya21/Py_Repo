# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
#variables

a = 15
b = 3.14
c = "Python"
d = True
a="vilva"

print(f"a = {a}, Type: {type(a)}")
print(f"b = {b}, Type: {type(b)}")
print(f"c = {c}, Type: {type(c)}")
print(f"d = {d}, Type: {type(d)}")
# Out:
# a = vilva, Type: <class 'str'>
# b = 3.14, Type: <class 'float'>
# c = Python, Type: <class 'str'>
# d = True, Type: <class 'bool'>

# %%
a,b=10,20
print(a+b,end=" ");print("Heloo ",111111," world"); #rarely used since it makes code less readable   

a="hello"
print(a[::-1])

print("He said \"Hi\"") # quotes inside string
c=b
d=20
print(id(c),id(b),id(d)) # both will have same id since both point to same object)

c,d=d,c # swapping values
# Out:
# 30 Heloo  111111  world
# olleh
# He said "Hi"
# 140715015841496 140715015841496 140715015841496

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
def count_up_to(n):
    i = 1
    while i <= n:
        yield i     # Pause here and send value to caller
        i += 1

counter = count_up_to(2)
print(next(counter))  # 1
print(next(counter))  # 2

# %%
x = 10
def modify():
    global x
    x = 20  # modifies global variable
    
modify()
print(x)

# %%
def outer():
    x = 10
    def inner():
        nonlocal x
        x = 20  # modifies 'x' in outer, not global
    inner()
    print(x)  # 20
outer()
# Out:
# 20

# %%
print('ⅮⅪ'.isdigit())
print('ⅮⅪ'.isnumeric())
# Out:
# False
# True
