# %%
l=[1,2,3]

for i in l:
    print(i)
else:
    print("done")
    
for i in range(2,5,3):
    print(i)
# Out:
# 1
# 2
# 3
# done
# 1
# 4

# %%
c=1
while(True):
    print("Hii")
    c+=1    
    if(c==5):
        break
# Out:
# Hii
# Hii
# Hii
# Hii

# %%
if (n := len([1,2,3])) > 2:
    print(f"List has {n} items")
# Out:
# List has 3 items

# %%
print(0 and 0) 
print(0 or None)
# Out:
# 0
# None

# %%
n=10
if n%2 == 0:
    print(f"{n} is even")
# Out:
# 10 is even

# %%
a=35
if(70<a<100):
    print("First Class")
elif 50<a<=70:
    print("Second Class")
elif 35<=a<=50:
    print("pass")
else:
    print("fail")
# Out:
# pass
