# %%
import math
print(math.sqrt(11))
# Out:
# 3.3166247903554

# %%
#specific function import
from math import sqrt
print(sqrt(16))

# %%
import math as m
print(m.factorial(5))

# %%
from math import pow as power
#from math import *#not recommended
print(power(2,3))
# Out:
# 8.0

# %%
import user_module
user_module.display()
# Out:
# Hello from user_module!

# %%
# import python.Functions as u
# u.func(1,2)

# %%
import importlib
import user_module

importlib.reload(user_module)
# Out:
# <module 'user_module' from 'c:\\Users\\Priya Koma\\Desktop\\Python_Practice_Repo\\python\\user_module.py'>
