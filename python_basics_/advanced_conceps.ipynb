# %%
from collections import Counter

list_example = [1,1,2,3,3,3,4,'a','b']
c = Counter(list_example)
dict_example = {'a':1,'b':2,'c':3,'d':4}
c_dict = Counter(dict_example)
print(c,"  ",c_dict)
# Out:
# Counter({3: 3, 1: 2, 2: 1, 4: 1, 'a': 1, 'b': 1})    Counter({'d': 4, 'c': 3, 'b': 2, 'a': 1})
