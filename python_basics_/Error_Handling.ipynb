# %%
try:
    n =0 #"vilva"
    res = 100 / n

except ZeroDivisionError:
    print("You can't divide by zero!")

else:
    print("Result is", res)

finally:
    print("Execution complete.")
# Out:
# You can't divide by zero!
# Execution complete.

# %%
try:
    int("me")
except ValueError:
    print("Enter a valid number!")

try:
    x = int(input("Enter number: "))
except ValueError:
    print("Not a number")
else:
    print("Valid input:", x)
# Out:
# Enter a valid number!

# %%
def type_error(a=10):
    return
try:
    type_error(11,"byee")

except TypeError:
    print("TypeError")

# %%
try:
    lst = [1, 2, 3]
    print(lst[5])  
except IndexError:
    print("List index out of range")
# Out:
# List index out of range

# %%
try:
    d = {"a": 10}
    print(d["b"])  
except KeyError:
    print("Key not present")
# Out:
# Key not present

# %%
try:
    with open('file.csv','r') as f:
        print("exist")
except FileNotFoundError:
    print("not present")
# Out:
# not present

# %%
try:
    import tensorflowx  # ModuleNotFoundError
except ModuleNotFoundError:
    print("module dont exist")
# Out:
# module dont exist

# %%
def set_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative")
set_age(-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2     if age < 0:
#       3         raise ValueError("Age cannot be negative")
# ----> 4 set_age(-1)
#
# Cell In[3], line 3, in set_age(age)
#       1 def set_age(age):
#       2     if age < 0:
# ----> 3         raise ValueError("Age cannot be negative")
#
# ValueError: Age cannot be negative
